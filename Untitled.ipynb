# %%
items['arts'] = np.where(items['main topic'].astype(str).str[0] == 'A', 1, 0)
items['arts_general'] = np.where(items['main topic'].astype(str).str[0:2] == 'AB', 1, 0)
items['arts_form'] = np.where(items['main topic'].astype(str).str[0:2] == 'AF', 1, 0)
items['arts_treatment'] = np.where(items['main topic'].astype(str).str[0:2] == 'AG', 1, 0)
items['arts_photography'] = np.where(items['main topic'].astype(str).str[0:2] == 'AJ', 1, 0)
items['arts_design'] = np.where(items['main topic'].astype(str).str[0:2] == 'AK', 1, 0)
items['arts_architecture'] = np.where(items['main topic'].astype(str).str[0:2] == 'AM', 1, 0)
items['arts_performing'] = np.where(items['main topic'].astype(str).str[0:2] == 'AT', 1, 0)
items['arts_music'] = np.where(items['main topic'].astype(str).str[0:2] == 'AV', 1, 0)

items['linguistic'] = np.where(items['main topic'].astype(str).str[0] == 'C', 1, 0)
items['linguistic_language_general'] = np.where(items['main topic'].astype(str).str[0:2] == 'CB', 1, 0)
items['linguistic_general'] = np.where(items['main topic'].astype(str).str[0:2] == 'CF', 1, 0)
items['linguistic_language_teaching'] = np.where(items['main topic'].astype(str).str[0:2] == 'CJ', 1, 0)

items['literature'] = np.where(items['main topic'].astype(str).str[0] == 'D', 1, 0)
items['literature_ancient'] = np.where(items['main topic'].astype(str).str[0:2] == 'DB', 1, 0)
items['literature_poetry'] = np.where(items['main topic'].astype(str).str[0:2] == 'DC', 1, 0)
items['literature_playscripts'] = np.where(items['main topic'].astype(str).str[0:2] == 'DD', 1, 0)
items['literature_biography'] = np.where(items['main topic'].astype(str).str[0:2] == 'DN', 1, 0)
items['literature_history'] = np.where(items['main topic'].astype(str).str[0:2] == 'DS', 1, 0)

items['fiction'] = np.where(items['main topic'].astype(str).str[0] == 'F', 1, 0)
items['fiction_general'] = np.where(items['main topic'].astype(str).str[0:2] == 'FB', 1, 0)
items['fiction_biography'] = np.where(items['main topic'].astype(str).str[0:2] == 'FC', 1, 0)
items['fiction_speculative'] = np.where(items['main topic'].astype(str).str[0:2] == 'FD', 1, 0)
items['fiction_crime'] = np.where(items['main topic'].astype(str).str[0:2] == 'FF', 1, 0)
items['fiction_sport'] = np.where(items['main topic'].astype(str).str[0:2] == 'FG', 1, 0)
items['fiction_thriller'] = np.where(items['main topic'].astype(str).str[0:2] == 'FH', 1, 0)
items['fiction_adventure'] = np.where(items['main topic'].astype(str).str[0:2] == 'FJ', 1, 0)
items['fiction_horror'] = np.where(items['main topic'].astype(str).str[0:2] == 'FK', 1, 0)
items['fiction_science'] = np.where(items['main topic'].astype(str).str[0:2] == 'FL', 1, 0)
items['fiction_fantasy'] = np.where(items['main topic'].astype(str).str[0:2] == 'FM', 1, 0)
items['fiction_myth'] = np.where(items['main topic'].astype(str).str[0:2] == 'FN', 1, 0)
items['fiction_erotic'] = np.where(items['main topic'].astype(str).str[0:2] == 'FP', 1, 0)
items['fiction_lifestyle_'] = np.where(items['main topic'].astype(str).str[0:2] == 'FQ', 1, 0)
items['fiction_romance'] = np.where(items['main topic'].astype(str).str[0:2] == 'FR', 1, 0)
items['fiction_family'] = np.where(items['main topic'].astype(str).str[0:2] == 'FS', 1, 0)
items['fiction_saga'] = np.where(items['main topic'].astype(str).str[0:2] == 'FT', 1, 0)
items['fiction_humour'] = np.where(items['main topic'].astype(str).str[0:2] == 'FU', 1, 0)
items['fiction_historical'] = np.where(items['main topic'].astype(str).str[0:2] == 'FV', 1, 0)
items['fiction_religious'] = np.where(items['main topic'].astype(str).str[0:2] == 'FW', 1, 0)
items['fiction_narrative'] = np.where(items['main topic'].astype(str).str[0:2] == 'FX', 1, 0)
items['fiction_special'] = np.where(items['main topic'].astype(str).str[0:2] == 'FY', 1, 0)
items['fiction_companion'] = np.where(items['main topic'].astype(str).str[0:2] == 'FZ', 1, 0)

items['reference'] = np.where(items['main topic'].astype(str).str[0] == 'G', 1, 0)
items['reference_encyclopedia'] = np.where(items['main topic'].astype(str).str[0:2] == 'GB', 1, 0)
items['reference_library'] = np.where(items['main topic'].astype(str).str[0:2] == 'GL', 1, 0)
items['reference_research'] = np.where(items['main topic'].astype(str).str[0:2] == 'GP', 1, 0)
items['reference_interdisciplinary'] = np.where(items['main topic'].astype(str).str[0:2] == 'GT', 1, 0)

items['society'] = np.where(items['main topic'].astype(str).str[0] == 'J', 1, 0)
items['society_culture'] = np.where(items['main topic'].astype(str).str[0:2] == 'JB', 1, 0)
items['society_anthropology'] = np.where(items['main topic'].astype(str).str[0:2] == 'JH', 1, 0)
items['society_welfare'] = np.where(items['main topic'].astype(str).str[0:2] == 'JK', 1, 0)
items['society_psychology'] = np.where(items['main topic'].astype(str).str[0:2] == 'JM', 1, 0)
items['society_education'] = np.where(items['main topic'].astype(str).str[0:2] == 'JN', 1, 0)
items['society_politics'] = np.where(items['main topic'].astype(str).str[0:2] == 'JP', 1, 0)
items['society_warfare'] = np.where(items['main topic'].astype(str).str[0:2] == 'JW', 1, 0)

items['economy'] = np.where(items['main topic'].astype(str).str[0] == 'K', 1, 0)
items['economy_economy'] = np.where(items['main topic'].astype(str).str[0:2] == 'KC', 1, 0)
items['economy_finance'] = np.where(items['main topic'].astype(str).str[0:2] == 'KF', 1, 0)
items['economy_business'] = np.where(items['main topic'].astype(str).str[0:2] == 'KJ', 1, 0)
items['economy_industry'] = np.where(items['main topic'].astype(str).str[0:2] == 'KN', 1, 0)

items['law'] = np.where(items['main topic'].astype(str).str[0] == 'L', 1, 0)
items['law_jurisprudence'] = np.where(items['main topic'].astype(str).str[0:2] == 'LA', 1, 0)
items['law_international'] = np.where(items['main topic'].astype(str).str[0:2] == 'LB', 1, 0)
items['law_specific'] = np.where(items['main topic'].astype(str).str[0:2] == 'LN', 1, 0)
items['law_shariah'] = np.where(items['main topic'].astype(str).str[0:2] == 'LW', 1, 0)
items['law_study'] = np.where(items['main topic'].astype(str).str[0:2] == 'LX', 1, 0)

items['medicine'] = np.where(items['main topic'].astype(str).str[0] == 'M', 1, 0)
items['medicine_general'] = np.where(items['main topic'].astype(str).str[0:2] == 'MB', 1, 0)
items['medicine_preclinical'] = np.where(items['main topic'].astype(str).str[0:2] == 'MF', 1, 0)
items['medicine_clinical'] = np.where(items['main topic'].astype(str).str[0:2] == 'MJ', 1, 0)
items['medicine_specialities'] = np.where(items['main topic'].astype(str).str[0:2] == 'MK', 1, 0)
items['medicine_surgery'] = np.where(items['main topic'].astype(str).str[0:2] == 'MN', 1, 0)
items['medicine_nursing'] = np.where(items['main topic'].astype(str).str[0:2] == 'MQ', 1, 0)
items['medicine_study'] = np.where(items['main topic'].astype(str).str[0:2] == 'MR', 1, 0)
items['medicine_complementary'] = np.where(items['main topic'].astype(str).str[0:2] == 'MX', 1, 0)
items['medicine_veterinary'] = np.where(items['main topic'].astype(str).str[0:2] == 'MZ', 1, 0)

items['history'] = np.where(items['main topic'].astype(str).str[0] == 'N', 1, 0)
items['history_history'] = np.where(items['main topic'].astype(str).str[0] == 'NH', 1, 0)
items['history_archaelogy'] = np.where(items['main topic'].astype(str).str[0] == 'NK', 1, 0)

items['science'] = np.where(items['main topic'].astype(str).str[0] == 'P', 1, 0)
items['science_math'] = np.where(items['main topic'].astype(str).str[0:2] == 'PB', 1, 0)
items['science_general'] = np.where(items['main topic'].astype(str).str[0:2] == 'PD', 1, 0)
items['science_astronomy'] = np.where(items['main topic'].astype(str).str[0:2] == 'PG', 1, 0)
items['science_physics'] = np.where(items['main topic'].astype(str).str[0:2] == 'PH', 1, 0)
items['science_chemistry'] = np.where(items['main topic'].astype(str).str[0:2] == 'PN', 1, 0)
items['science_biology'] = np.where(items['main topic'].astype(str).str[0:2] == 'PS', 1, 0)

items['philosophy'] = np.where(items['main topic'].astype(str).str[0] == 'Q', 1, 0)
items['philosophy_philosophy'] = np.where(items['main topic'].astype(str).str[0:2] == 'QD', 1, 0)
items['philosophy_religion'] = np.where(items['main topic'].astype(str).str[0:2] == 'QR', 1, 0)

items['geography'] = np.where(items['main topic'].astype(str).str[0] == 'R', 1, 0)
items['geography_earth'] = np.where(items['main topic'].astype(str).str[0:2] == 'RB', 1, 0)
items['geography_geography'] = np.where(items['main topic'].astype(str).str[0:2] == 'RG', 1, 0)
items['geography_environment'] = np.where(items['main topic'].astype(str).str[0:2] == 'RN', 1, 0)
items['geography_regional'] = np.where(items['main topic'].astype(str).str[0:2] == 'RP', 1, 0)

items['sports'] = np.where(items['main topic'].astype(str).str[0] == 'S', 1, 0)
items['sports_general'] = np.where(items['main topic'].astype(str).str[0:2] == 'SC', 1, 0)
items['sports_ball'] = np.where(items['main topic'].astype(str).str[0:2] == 'SF', 1, 0)
items['sports_athletic'] = np.where(items['main topic'].astype(str).str[0:2] == 'SH', 1, 0)
items['sports_animal'] = np.where(items['main topic'].astype(str).str[0:2] == 'SK', 1, 0)
items['sports_vehicle'] = np.where(items['main topic'].astype(str).str[0:2] == 'SM', 1, 0)
items['sports_water'] = np.where(items['main topic'].astype(str).str[0:2] == 'SP', 1, 0)
items['sports_combat'] = np.where(items['main topic'].astype(str).str[0:2] == 'SR', 1, 0)
items['sports_winter'] = np.where(items['main topic'].astype(str).str[0:2] == 'ST', 1, 0)
items['sports_field'] = np.where(items['main topic'].astype(str).str[0:2] == 'SV', 1, 0)
items['sports_other'] = np.where(items['main topic'].astype(str).str[0:2] == 'SX', 1, 0)
items['sports_outdoor'] = np.where(items['main topic'].astype(str).str[0:2] == 'SZ', 1, 0)

items['technology'] = np.where(items['main topic'].astype(str).str[0] == 'T', 1, 0)
items['technology_general'] = np.where(items['main topic'].astype(str).str[0:2] == 'TB', 1, 0)
items['technology_biochemical'] = np.where(items['main topic'].astype(str).str[0:2] == 'TC', 1, 0)
items['technology_industrial'] = np.where(items['main topic'].astype(str).str[0:2] == 'TD', 1, 0)
items['technology_mechanical'] = np.where(items['main topic'].astype(str).str[0:2] == 'TG', 1, 0)
items['technology_energy'] = np.where(items['main topic'].astype(str).str[0:2] == 'TH', 1, 0)
items['technology_electronics'] = np.where(items['main topic'].astype(str).str[0:2] == 'TJ', 1, 0)
items['technology_civil'] = np.where(items['main topic'].astype(str).str[0:2] == 'TN', 1, 0)
items['technology_environmental'] = np.where(items['main topic'].astype(str).str[0:2] == 'TQ', 1, 0)
items['technology_transport'] = np.where(items['main topic'].astype(str).str[0:2] == 'TR', 1, 0)
items['technology_other'] = np.where(items['main topic'].astype(str).str[0:2] == 'TT', 1, 0)
items['technology_agriculture'] = np.where(items['main topic'].astype(str).str[0:2] == 'TV', 1, 0)

items['computing'] = np.where(items['main topic'].astype(str).str[0] == 'U', 1, 0)
items['computing_general'] = np.where(items['main topic'].astype(str).str[0:2] == 'UB', 1, 0)
items['computing_lifestyle'] = np.where(items['main topic'].astype(str).str[0:2] == 'UD', 1, 0)
items['computing_business'] = np.where(items['main topic'].astype(str).str[0:2] == 'UF', 1, 0)
items['computing_graphical'] = np.where(items['main topic'].astype(str).str[0:2] == 'UG', 1, 0)
items['computing_hardware'] = np.where(items['main topic'].astype(str).str[0:2] == 'UK', 1, 0)
items['computing_OS'] = np.where(items['main topic'].astype(str).str[0:2] == 'UL', 1, 0)
items['computing_programming'] = np.where(items['main topic'].astype(str).str[0:2] == 'UM', 1, 0)
items['computing_database'] = np.where(items['main topic'].astype(str).str[0:2] == 'UN', 1, 0)
items['computing_practical'] = np.where(items['main topic'].astype(str).str[0:2] == 'UP', 1, 0)
items['computing_certification'] = np.where(items['main topic'].astype(str).str[0:2] == 'UQ', 1, 0)
items['computing_security'] = np.where(items['main topic'].astype(str).str[0:2] == 'UR', 1, 0)
items['computing_networking'] = np.where(items['main topic'].astype(str).str[0:2] == 'UT', 1, 0)
items['computing_applied'] = np.where(items['main topic'].astype(str).str[0:2] == 'UX', 1, 0)
items['computing_science'] = np.where(items['main topic'].astype(str).str[0:2] == 'UY', 1, 0)

items['health'] = np.where(items['main topic'].astype(str).str[0] == 'V', 1, 0)
items['health_family'] = np.where(items['main topic'].astype(str).str[0:2] == 'VF', 1, 0)
items['health_self_help'] = np.where(items['main topic'].astype(str).str[0:2] == 'VS', 1, 0)
items['health_mind'] = np.where(items['main topic'].astype(str).str[0:2] == 'VX', 1, 0)

items['lifestyle'] = np.where(items['main topic'].astype(str).str[0] == 'W', 1, 0)
items['lifestyle_food'] = np.where(items['main topic'].astype(str).str[0:2] == 'WB', 1, 0)
items['lifestyle_antique'] = np.where(items['main topic'].astype(str).str[0:2] == 'WC', 1, 0)
items['lifestyle_hobby'] = np.where(items['main topic'].astype(str).str[0:2] == 'WD', 1, 0)
items['lifestyle_decoration'] = np.where(items['main topic'].astype(str).str[0:2] == 'WF', 1, 0)
items['lifestyle_transport'] = np.where(items['main topic'].astype(str).str[0:2] == 'WG', 1, 0)
items['lifestyle_humour'] = np.where(items['main topic'].astype(str).str[0:2] == 'WH', 1, 0)
items['lifestyle_fashion'] = np.where(items['main topic'].astype(str).str[0:2] == 'WJ', 1, 0)
items['lifestyle_house'] = np.where(items['main topic'].astype(str).str[0:2] == 'WK', 1, 0)
items['lifestyle_gardening'] = np.where(items['main topic'].astype(str).str[0:2] == 'WM', 1, 0)
items['lifestyle_nature'] = np.where(items['main topic'].astype(str).str[0:2] == 'WN', 1, 0)
items['lifestyle_history'] = np.where(items['main topic'].astype(str).str[0:2] == 'WQ', 1, 0)
items['lifestyle_travel'] = np.where(items['main topic'].astype(str).str[0:2] == 'WT', 1, 0)
items['lifestyle_miscellaneous'] = np.where(items['main topic'].astype(str).str[0:2] == 'WZ', 1, 0)

items['comic'] = np.where(items['main topic'].astype(str).str[0] == 'X', 1, 0)
items['comic_type'] = np.where(items['main topic'].astype(str).str[0:2] == 'XA', 1, 0)
items['comic_genre'] = np.where(items['main topic'].astype(str).str[0:2] == 'XQ', 1, 0)
items['comic_review'] = np.where(items['main topic'].astype(str).str[0:2] == 'XR', 1, 0)
items['comic_strip_cartoon'] = np.where(items['main topic'].astype(str).str[0:2] == 'XY', 1, 0)

items['children'] = np.where(items['main topic'].astype(str).str[0] == 'Y', 1, 0)
items['children_picture'] = np.where(items['main topic'].astype(str).str[0:2] == 'YB', 1, 0)
items['children_poetry'] = np.where(items['main topic'].astype(str).str[0:2] == 'YD', 1, 0)
items['children_fiction'] = np.where(items['main topic'].astype(str).str[0:2] == 'YF', 1, 0)
items['children_general'] = np.where(items['main topic'].astype(str).str[0:2] == 'YN', 1, 0)
items['children_education'] = np.where(items['main topic'].astype(str).str[0:2] == 'YP', 1, 0)
items['children_reference'] = np.where(items['main topic'].astype(str).str[0:2] == 'YR', 1, 0)
items['children_social'] = np.where(items['main topic'].astype(str).str[0:2] == 'YX', 1, 0)
items['children_miscelaneous'] = np.where(items['main topic'].astype(str).str[0:2] == 'YZ', 1, 0)

# %%
items['GarciaSantiago']=np.where(items['author']=='Garcia Santiago',1,0)
items['ShelleyAdmont,KidkiddosBooks']=np.where(items['author']=='Shelley Admont, Kidkiddos Books',1,0)
items['JamesManning']=np.where(items['author']=='James Manning',1,0)
items['JulesVerne']=np.where(items['author']=='Jules Verne',1,0)
items['IdriesShah']=np.where(items['author']=='Idries Shah',1,0)
items['ErinHunter']=np.where(items['author']=='Erin Hunter',1,0)
items['EnidBlyton']=np.where(items['author']=='Enid Blyton',1,0)
items['R.L.Stine']=np.where(items['author']=='R. L. Stine',1,0)
items['TerryPratchett']=np.where(items['author']=='Terry Pratchett',1,0)
items['SpeedyPublishingLlc']=np.where(items['author']=='Speedy Publishing Llc',1,0)
items['H.G.Wells']=np.where(items['author']=='H. G. Wells',1,0)
items['RogerHargreaves']=np.where(items['author']=='Roger Hargreaves',1,0)
items['SteveHerman']=np.where(items['author']=='Steve Herman',1,0)
items['TuulaPere']=np.where(items['author']=='Tuula Pere',1,0)
items['DaisyMeadows']=np.where(items['author']=='Daisy Meadows',1,0)
items['ElBlokehead']=np.where(items['author']=='El Blokehead',1,0)
items['RoaldDahl']=np.where(items['author']=='Roald Dahl',1,0)
items['LewisCarroll']=np.where(items['author']=='Lewis Carroll',1,0)
items['AlfredBekker']=np.where(items['author']=='Alfred Bekker',1,0)
items['PenelopeDyan']=np.where(items['author']=='Penelope Dyan',1,0)
items['FionaWatt']=np.where(items['author']=='Fiona Watt',1,0)
items['MichelleM.Pillow']=np.where(items['author']=='Michelle M. Pillow',1,0)
items['L.FrankBaum']=np.where(items['author']=='L. Frank Baum',1,0)
items['MatildeCorreia']=np.where(items['author']=='Matilde Correia',1,0)
items['GinoBianchi']=np.where(items['author']=='Gino Bianchi',1,0)
items['NorbertPautner']=np.where(items['author']=='Norbert Pautner',1,0)
items['BrandonSanderson']=np.where(items['author']=='Brandon Sanderson',1,0)
items['CaroleMarsh']=np.where(items['author']=='Carole Marsh',1,0)
items['CarolynKeene']=np.where(items['author']=='Carolyn Keene',1,0)
items['MichaelMorpurgo']=np.where(items['author']=='Michael Morpurgo',1,0)
items['JenniferL.Armentrout']=np.where(items['author']=='Jennifer L. Armentrout',1,0)
items['DanGutman']=np.where(items['author']=='Dan Gutman',1,0)
items['RickRiordan']=np.where(items['author']=='Rick Riordan',1,0)
items['L.M.Montgomery']=np.where(items['author']=='L. M. Montgomery',1,0)
items['Thithiajobs']=np.where(items['author']=='Thithiajobs',1,0)
items['PeterHertzberg']=np.where(items['author']=='Peter Hertzberg',1,0)
items['JacquelineWilson']=np.where(items['author']=='Jacqueline Wilson',1,0)
items['GraceGoodwin']=np.where(items['author']=='Grace Goodwin',1,0)
items['CassandraClare']=np.where(items['author']=='Cassandra Clare',1,0)
items['LouisaMayAlcott']=np.where(items['author']=='Louisa May Alcott',1,0)
items['JeffKinney']=np.where(items['author']=='Jeff Kinney',1,0)
items['J.R.R.Tolkien']=np.where(items['author']=='J. R. R. Tolkien',1,0)
items['MaryPopeOsborne']=np.where(items['author']=='Mary Pope Osborne',1,0)
items['Panini']=np.where(items['author']=='Panini',1,0)
items['J.R.Ward']=np.where(items['author']=='J. R. Ward',1,0)
items['GeorgeR.R.Martin']=np.where(items['author']=='George R. R. Martin',1,0)
items['SaraShepard']=np.where(items['author']=='Sara Shepard',1,0)
items['JakeMaddox']=np.where(items['author']=='Jake Maddox',1,0)
items['MarkusHeitz']=np.where(items['author']=='Markus Heitz',1,0)
items['LincolnPeirce']=np.where(items['author']=='Lincoln Peirce',1,0)

top50_author = items['author'].value_counts()[:50].index.tolist()
items['other_author'] = np.where(~np.isin(items['author'], [top50_author]), 1, 0)
